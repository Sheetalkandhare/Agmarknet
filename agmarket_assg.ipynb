# %%
import pandas as pd
import datetime
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Agmarket_assg.csv')

# %%
df.head(5)
# Out:
#    Sl no. District Name Market Name Commodity Variety Grade  \
# 0       1          Agra     Achnera    Potato    Desi   FAQ
# 1       2          Agra     Achnera    Potato    Desi   FAQ
# 2       3          Agra     Achnera    Potato    Desi   FAQ
# 3       4          Agra     Achnera    Potato    Desi   FAQ
# 4       5          Agra     Achnera    Potato    Desi   FAQ
#
#    Min Price (Rs./Quintal)  Max Price (Rs./Quintal)  \
# 0                      750                      830
# 1                      710                      770
# 2                      710                      790
# 3                      690                      790
# 4                      700                      780
#
#    Modal Price (Rs./Quintal) Price Date
# 0                        790  30-Apr-21
# 1                        740  28-Apr-21
# 2                        750  27-Apr-21
# 3                        740  25-Apr-21
# 4                        740  24-Apr-21

# %%
df.tail(5)
# Out:
#       Sl no. District Name Market Name Commodity Variety Grade  \
# 8802    8803          Agra    Samsabad    Potato  Potato   FAQ
# 8803    8804          Agra    Samsabad    Potato  Potato   FAQ
# 8804    8805          Agra    Samsabad    Potato   Other   FAQ
# 8805    8806          Agra    Samsabad    Potato   Other   FAQ
# 8806    8807          Agra    Samsabad    Potato   Other   FAQ
#
#       Min Price (Rs./Quintal)  Max Price (Rs./Quintal)  \
# 8802                        0                        0
# 8803                        0                        0
# 8804                        0                        0
# 8805                        0                        0
# 8806                        0                        0
#
#       Modal Price (Rs./Quintal) Price Date
# 8802                        400   6-Mar-17
# 8803                        375   5-Mar-17
# 8804                        320   1-Mar-17
# 8805                        410  28-Feb-17
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Sl no.                     8807 non-null   int64
#  1   District Name              8807 non-null   object
#  2   Market Name                8807 non-null   object
#  3   Commodity                  8807 non-null   object
#  4   Variety                    8807 non-null   object
#  5   Grade                      8807 non-null   object
#  6   Min Price (Rs./Quintal)    8807 non-null   int64
#  7   Max Price (Rs./Quintal)    8807 non-null   int64
#  8   Modal Price (Rs./Quintal)  8807 non-null   int64
#  9   Price Date                 8807 non-null   object
# dtypes: int64(4), object(6)
# memory usage: 688.2+ KB

# %%
df["Price Date"]=pd.to_datetime(df["Price Date"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Sl no.                     8807 non-null   int64
#  1   District Name              8807 non-null   object
#  2   Market Name                8807 non-null   object
#  3   Commodity                  8807 non-null   object
#  4   Variety                    8807 non-null   object
#  5   Grade                      8807 non-null   object
#  6   Min Price (Rs./Quintal)    8807 non-null   int64
#  7   Max Price (Rs./Quintal)    8807 non-null   int64
#  8   Modal Price (Rs./Quintal)  8807 non-null   int64
#  9   Price Date                 8807 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), int64(4), object(5)
# memory usage: 688.2+ KB

# %%
df.set_index("Price Date").head(5)
# Out:
#             Sl no. District Name Market Name Commodity Variety Grade  \
# Price Date
# 2021-04-30       1          Agra     Achnera    Potato    Desi   FAQ
# 2021-04-28       2          Agra     Achnera    Potato    Desi   FAQ
# 2021-04-27       3          Agra     Achnera    Potato    Desi   FAQ
# 2021-04-25       4          Agra     Achnera    Potato    Desi   FAQ
# 2021-04-24       5          Agra     Achnera    Potato    Desi   FAQ
#
#             Min Price (Rs./Quintal)  Max Price (Rs./Quintal)  \
# Price Date
# 2021-04-30                      750                      830
# 2021-04-28                      710                      770
# 2021-04-27                      710                      790
# 2021-04-25                      690                      790
# 2021-04-24                      700                      780
#
#             Modal Price (Rs./Quintal)
# Price Date
# 2021-04-30                        790
# 2021-04-28                        740
# ...

# %% [markdown]
# # Between a range of date(1st jan 2020 to 31st dec 2020)

# %%
df = df.sort_values(by="Price Date")    
df =df[df["Price Date"].between('2020-01-01','2020-12-31')]
df
# Out:
#       Sl no. District Name     Market Name Commodity Variety Grade  \
# 400      401          Agra         Achnera    Potato    Desi   FAQ
# 6977    6978          Agra      Khairagarh    Potato    Desi   FAQ
# 8006    8007          Agra        Samsabad    Potato   Local   FAQ
# 3957    3958          Agra  Fatehpur Sikri    Potato   Local   FAQ
# 5026    5027          Agra         Jagnair    Potato    Desi   FAQ
# ...      ...           ...             ...       ...     ...   ...
# 2581    2582          Agra       Fatehabad    Potato    Desi   FAQ
# 120      121          Agra         Achnera    Potato    Desi   FAQ
# 6820    6821          Agra      Khairagarh    Potato    Desi   FAQ
# 4865    4866          Agra         Jagnair    Potato    Desi   FAQ
# 2580    2581          Agra       Fatehabad    Potato    Desi   FAQ
#
#       Min Price (Rs./Quintal)  Max Price (Rs./Quintal)  \
# 400                      1300                     1400
# ...

# %%
#TO ENTER A RANGE OD DATE (DATE WISE BETWEEN ANY RANGE)
start = input('Enter a date in YYYY-MM-DD format')
year, month, day = map(int, date_entry.split('-'))
date1 = datetime.date(year, month, day)
end = input('Enter a date in YYYY-MM-DD format')
year, month, day = map(int, date_entry.split('-'))
date2 = datetime.date(year, month, day)

df = df.sort_values(by="Price Date")    
df =df[df["Price Date"].between(start,end)]
df
# Out:
# Enter a date in YYYY-MM-DD format2020-01-01
# Enter a date in YYYY-MM-DD format2020-05-31
#       Sl no. District Name     Market Name Commodity Variety Grade  \
# 400      401          Agra         Achnera    Potato    Desi   FAQ
# 6977    6978          Agra      Khairagarh    Potato    Desi   FAQ
# 8006    8007          Agra        Samsabad    Potato   Local   FAQ
# 3957    3958          Agra  Fatehpur Sikri    Potato   Local   FAQ
# 5026    5027          Agra         Jagnair    Potato    Desi   FAQ
# ...      ...           ...             ...       ...     ...   ...
# 6853    6854          Agra      Khairagarh    Potato    Desi   FAQ
# 1499    1500          Agra            Agra    Potato    Desi   FAQ
# 5882    5883          Agra           Jarar    Potato    Desi   FAQ
# 274      275          Agra         Achnera    Potato    Desi   FAQ
# 7871    7872          Agra        Samsabad    Potato   Local   FAQ
#
#       Min Price (Rs./Quintal)  Max Price (Rs./Quintal)  \
# ...

# %%
df["Market Name"]
# Out:
# 400            Achnera
# 6977        Khairagarh
# 8006          Samsabad
# 3957    Fatehpur Sikri
# 5026           Jagnair
#              ...
# 6853        Khairagarh
# 1499              Agra
# 5882             Jarar
# 274            Achnera
# 7871          Samsabad
# Name: Market Name, Length: 961, dtype: object

# %%
df1=pd.value_counts(df['Market Name'],ascending= False)
df1
# Out:
# Samsabad          136
# Achnera           127
# Khairagarh        125
# Jagnair           122
# Jarar             121
# Fatehpur Sikri    114
# Agra              112
# Fatehabad         104
# Name: Market Name, dtype: int64

# %%
df1.hist(grid=True,xlabelsize=8,xrot=90.44,bins=15)

# %% [markdown]
# Here,we can observe samsabad having the maximum market sales with upto 136 counts between jan 2020 and dec 2020
